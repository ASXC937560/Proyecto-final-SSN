# %% [markdown]
# # Visualization of a fdf structure

# %% [markdown]
# Import libraries

# %%
import sisl as si

# %%
molecula=si.Geometry.read("serotonin.fdf")

# %%
print(molecula)
# Out:
# Geometry{na: 25, no: 25,
#  Atoms{species: 4,
#   Atom{C, Z: 6, mass(au): 12.01070, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 10,
#   Atom{N, Z: 7, mass(au): 14.00670, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 2,
#   Atom{H, Z: 1, mass(au): 1.00794, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 12,
#   Atom{O, Z: 8, mass(au): 15.99940, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 1,
#  },
#  maxR: -1.00000,
#  Lattice{nsc: [1 1 1],
#   origin=[0.0000, 0.0000, 0.0000],
#   A=[16.5189, 0.0000, 0.0000],
#   B=[0.0000, 18.3780, 0.0000],
#   C=[0.0000, 0.0000, 13.3917],
#   bc=[Periodic,
#       Periodic,
#       Periodic]
#  }
# }

# %%
molecula.plot()

# %%
sero_centered=molecula.move((8,10,6))

# %%
sero_centered.plot()
