# %% [markdown]
# # Visualization of a fdf structure

# %% [markdown]
# Import libraries

# %%
import sisl as si

# %%
molecula=si.Geometry.read("DMT.fdf")

# %%
print(molecula)
# Out:
# Geometry{na: 31, no: 31,
#  Atoms{species: 4,
#   Atom{C, Z: 6, mass(au): 12.01070, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 12,
#   Atom{N, Z: 7, mass(au): 14.00670, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 2,
#   Atom{H, Z: 1, mass(au): 1.00794, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 16,
#   Atom{O, Z: 8, mass(au): 15.99940, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 1,
#  },
#  maxR: -1.00000,
#  Lattice{nsc: [1 1 1],
#   origin=[0.0000, 0.0000, 0.0000],
#   A=[15.7475, 0.0000, 0.0000],
#   B=[0.0000, 21.0679, 0.0000],
#   C=[0.0000, 0.0000, 13.5556],
#   bc=[Periodic,
#       Periodic,
#       Periodic]
#  }
# }

# %%
molecula.plot()

# %%
bufo_centered=molecula.move((10,10,8))

# %%
bufo_centered.plot()
